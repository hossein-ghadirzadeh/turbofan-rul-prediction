# %%
import sys
import os
import matplotlib.pyplot as plt
import numpy as np

sys.path.append(os.path.abspath(os.path.join('..')))

from src.data_process import load_data, process_targets, scale_data, make_sequences

TRAIN_PATH = '../data/train_FD001.txt'
TEST_PATH = '../data/test_FD001.txt'
RUL_PATH = '../data/RUL_FD001.txt'

# 1. Load
train, test, rul = load_data(TRAIN_PATH, TEST_PATH, RUL_PATH)
print("Data Loaded. Train shape:", train.shape)

# 2. RUL Calculation
train = process_targets(train)
print("RUL Calculated. Example:", train['RUL'].head())

# 3. Scaling
train, test, scaler = scale_data(train, test)
print("Data Scaled.")

# 4. Sequence Generation (The Hard Part!)
SEQUENCE_LENGTH = 30
X_train, y_train = make_sequences(train, seq_length=SEQUENCE_LENGTH)

print("\n--- FINAL SHAPES FOR LSTM ---")
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# Data Loaded. Train shape: (20631, 26)
# RUL Calculated. Example: 0    125
# 1    125
# 2    125
# 3    125
# 4    125
# Name: RUL, dtype: int64
# Data Scaled.
#
# --- FINAL SHAPES FOR LSTM ---
# X_train shape: (17631, 30, 14)
# y_train shape: (17631, 1)
